# %%
# Import required libraries
import sys
from pathlib import Path
import numpy as np

# Add parent directory to path
sys.path.insert(0, str(Path.cwd().parent))

from config.config import *
from src.models.model2 import BinaryClassification
import src.utils as ut
from sklearn.metrics import accuracy_score, roc_auc_score
from persim import wasserstein, bottleneck

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %%
# Load train, test datasets
train_dataset = ut.SeismicDataset(data_path=Path("../data/processed/signals_train.hdf5"))
test_dataset = ut.SeismicDataset(data_path=Path("../data/processed/signals_test.hdf5"))

X_train, y_train, mag_train = train_dataset.get_data()
X_test, y_test, mag_test = test_dataset.get_data()

print(f"\n✓ Datasets loaded successfully")
print(f"  Train: {len(train_dataset)} signals")
print(f"  Test: {len(test_dataset)} signals")
print(f"\nSample (signal, label, magnitude): {train_dataset[0]}")
# Out:
# ✓ Datasets loaded successfully
#   Train: 135 signals
#   Test: 36 signals
#
# Sample (signal, label, magnitude): (array([-124.9554206 , -225.88744057, -196.81946055, ...,  295.16472371,
#         834.23270373, 1175.30068375]), 1, 4.4)

# %%
# Initialize model
model = BinaryClassification(
    distance=bottleneck,
    weigths=[2, 1],
    dim=20,
    tau=5,
    stride=2,
    maxdim=1,
    sample=10,
    thresh=np.inf,
    alpha=0.1
)

# Fit model
model.fit(X_train, y_train)

# %%
# Evaluate model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Evaluate model
# ----> 2 y_pred = model.predict(X_test)
#       3 accuracy = accuracy_score(y_test, y_pred)
#       4 print(f"Accuracy: {accuracy:.4f}")
#
# File c:\Users\aaron\Documents\Topología aplicada y análisis topológico de datos\seismic-signals-tda\src\models\model2.py:104, in BinaryClassification.predict(self, X)
#      97 def predict(self, X):
#      98     """ Predict class labels for multiple samples.
#      99     Args:
#     100         X: List[ndarray] (n_samples, ~n_signals)
#     101     Returns:
#     102         labels: List[int] of predicted labels (0 or 1)
#     103     """
# --> 104     probs = self.predict_proba(X)
#     105     labels = [1 if p >= 0.5 else 0 for p in probs]
#     106     return labels
#
# File c:\Users\aaron\Documents\Topología aplicada y análisis topológico de datos\seismic-signals-tda\src\models\model2.py:94, in BinaryClassification.predict_proba(self, X)
#      87 def predict_proba(self, X):
#      88     """ Predict probabilities for multiple samples.
#      89     Args:
#      90         X: List[ndarray] (n_samples, ~n_signals)
#      91     Returns:
#      92         probs: List[float] of probabilities in [0, 1]
#      93     """
# ---> 94     probs = [self.predict_proba_sample(xs) for xs in X]
#      95     return probs
#
# File c:\Users\aaron\Documents\Topología aplicada y análisis topológico de datos\seismic-signals-tda\src\models\model2.py:62, in BinaryClassification.predict_proba_sample(self, xs)
#      59 N_h0 = self.get_diagrams(label=0, dim=d)
#      61 # Compute distances
# ---> 62 dists_E = [self.distance(xs_dgm[d], dgm) for dgm in E_h0]
#      63 dists_N = [self.distance(xs_dgm[d], dgm) for dgm in N_h0]
#      65 mean_dist_E.append(np.mean(dists_E) if dists_E else np.inf)
#
# File c:\Users\aaron\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\bottleneck.py:112, in bottleneck(dgm1, dgm2, matching)
#     110 for i in range(D.shape[0]):
#     111     graph["{}".format(i)] = {j for j in range(D.shape[1]) if D[i, j] <= d}
# --> 112 res = HopcroftKarp(graph).maximum_matching()
#     113 if len(res) == 2 * D.shape[0] and d <= bdist:
#     114     bdist = d
#
# File c:\Users\aaron\AppData\Local\Programs\Python\Python312\Lib\site-packages\hopcroftkarp\__init__.py:115, in HopcroftKarp.maximum_matching(self, keys_only)
#     113 def maximum_matching(self, keys_only=False):
#     114     while True:
# --> 115         layers = self.__bfs()
#     116         # we break out of the whole while loop if the most recent layer added to layers is empty
#     117         # since if there are no vertices in the recent layer, then there is no way augmenting paths can be found
#     118         if len(layers[-1]) == 0:
#
# File c:\Users\aaron\AppData\Local\Programs\Python\Python312\Lib\site-packages\hopcroftkarp\__init__.py:70, in HopcroftKarp.__bfs(self)
#      66         visited.add(vertex)  # we don't want to traverse the vertex again
#      67         for neighbour in self._graph[vertex]:
#      68             # check if the neighbour is not already visited
#      69             # check if vertex is in the matching and if the edge between vertex and neighbour is matched
# ---> 70             if neighbour not in visited and (vertex in self._matching and neighbour == self._matching[vertex]):
#      71                 new_layer.add(neighbour)
#      72 layers.append(new_layer)  # we add the new layer to the set of layers
#
# KeyboardInterrupt:
